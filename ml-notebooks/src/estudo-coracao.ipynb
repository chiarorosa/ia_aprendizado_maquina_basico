# %%
import numpy as np
import pandas as pd

df = pd.read_csv('../../ml-dataset/kaggle-basico/heart_Disease.csv') # Carregando o dataset
meuSeed = 42 # Definindo uma semente para o random

# Algoritmos de classificação
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

from sklearn.metrics import classification_report

# %%
df.iloc[0:10]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.target.value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
X = df.iloc[:,:-1] # Todas as colunas, exceto Classe
y = df.target # Apenas a coluna Classe

# Normalizando os dados de X para uma escala entre 0 e 1
X_normalizado = (X - X.min()) / (X.max() - X.min())

print('{} \n {}'.format(
    X.iloc[0:5], # .head()
    X_normalizado.iloc[0:5]
    ))
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2
#          age  sex        cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.708333  1.0  1.000000  0.481132  0.244292  1.0      0.0  0.603053    0.0
# 1  0.166667  1.0  0.666667  0.339623  0.283105  0.0      0.5  0.885496    0.0
# 2  0.250000  0.0  0.333333  0.339623  0.178082  0.0      0.0  0.770992    0.0
# 3  0.562500  1.0  0.333333  0.245283  0.251142  0.0      0.5  0.816794    0.0
# 4  0.583333  0.0  0.000000  0.245283  0.520548  0.0      0.5  0.702290    1.0
#
#     oldpeak  slope   ca      thal
# 0  0.370968    0.0  0.0  0.333333
# 1  0.564516    0.0  0.0  0.666667
# 2  0.225806    1.0  0.0  0.666667
# 3  0.129032    1.0  0.0  0.666667
# 4  0.096774    1.0  0.0  0.666667

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_padronizado = scaler.fit_transform(X)
X_padronizado = pd.DataFrame(X_padronizado, columns=X.columns.values)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.2, random_state=meuSeed)

# %%
# Instanciar o modelo com 3 vizinhos
modeloKNN = KNeighborsClassifier(n_neighbors=3)
# Ajustar o modelo aos dados de treino (treinar)
modeloKNN.fit(X_train, y_train)

print('Acurácia do modelo KNN: {:.2f}%'.format(
    modeloKNN.score(X_test, y_test)*100
    ))

# Instanciar o modelo com 3 vizinhos
modeloTree = DecisionTreeClassifier(random_state=meuSeed)
# Ajustar o modelo aos dados de treino (treinar)
modeloTree.fit(X_train, y_train)

print('Acurácia do modelo DT: {:.2f}%'.format(
    modeloTree.score(X_test, y_test)*100
    ))

# Instanciar o modelo SVM com um kernel (por exemplo, linear)
modeloSVM = SVC(kernel='linear', random_state=meuSeed)
# Ajustar o modelo aos dados de treino (treinar)
modeloSVM.fit(X_train, y_train)

print('Acurácia do modelo SVM: {:.2f}%'.format(
    modeloSVM.score(X_test, y_test) * 100
))
# Out:
# Acurácia do modelo KNN: 65.57%
# Acurácia do modelo DT: 75.41%
# Acurácia do modelo SVM: 86.89%

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_padronizado, y, 
                                                    test_size = 0.2, random_state=meuSeed)

# %%
# Instanciar o modelo com 3 vizinhos
modeloKNN = KNeighborsClassifier(n_neighbors=5)
# Ajustar o modelo aos dados de treino (treinar)
modeloKNN.fit(X_train, y_train)

print('Acurácia do modelo KNN: {:.2f}%'.format(
    modeloKNN.score(X_test, y_test)*100
    ))

# Instanciar o modelo com 3 vizinhos
modeloTree = DecisionTreeClassifier(random_state=meuSeed)
# Ajustar o modelo aos dados de treino (treinar)
modeloTree.fit(X_train, y_train)

print('Acurácia do modelo DT: {:.2f}%'.format(
    modeloTree.score(X_test, y_test)*100
    ))

# Instanciar o modelo SVM com um kernel (por exemplo, linear)
modeloSVM = SVC(kernel='linear', random_state=meuSeed)
# Ajustar o modelo aos dados de treino (treinar)
modeloSVM.fit(X_train, y_train)

print('Acurácia do modelo SVM: {:.2f}%'.format(
    modeloSVM.score(X_test, y_test) * 100
))
# Out:
# Acurácia do modelo KNN: 91.80%
# Acurácia do modelo DT: 75.41%
# Acurácia do modelo SVM: 86.89%

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.2, random_state=meuSeed)

# %%
y_train.value_counts()
# Out:
# target
# 1    133
# 0    109
# Name: count, dtype: int64

# %%
X_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 132   42    1   1       120   295    0        1      162      0      0.0
# 202   58    1   0       150   270    0        0      111      1      0.8
# 196   46    1   2       150   231    0        1      147      0      3.6
# 75    55    0   1       135   250    0        0      161      0      1.4
# 176   60    1   0       117   230    1        1      160      1      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 188   50    1   2       140   233    0        1      163      0      0.6
# 71    51    1   2        94   227    0        1      154      1      0.0
# 106   69    1   3       160   234    1        0      131      0      0.1
# 270   46    1   0       120   249    0        0      144      0      0.8
# 102   63    0   1       140   195    0        1      179      0      0.0
#
#      slope  ca  thal
# 132      2   0     2
# 202      2   0     3
# 196      1   0     2
# 75       1   0     2
# 176      2   2     3
# ..     ...  ..   ...
# 188      1   1     3
# 71       2   1     3
# 106      1   1     2
# 270      2   0     3
# 102      2   2     2
#
# [242 rows x 13 columns]

# %%
from sklearn.utils import resample

X_reamostrado, y_reamostrado = resample(X_train, y_train, n_samples=1000, random_state=meuSeed)

# %%
y_reamostrado.value_counts()
# Out:
# target
# 1    563
# 0    437
# Name: count, dtype: int64

# %%
X_negativo = X_reamostrado[y_reamostrado == 0]
X_positivo = X_reamostrado[y_reamostrado == 1]

# %%
X_negativo.shape
# Out:
# (437, 13)

# %%
X_positivo.shape
# Out:
# (563, 13)

# %%
X_positivo.loc[:,'target'] = 1
X_negativo.loc[:,'target'] = 0
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_10032\2281335036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_positivo.loc[:,'target'] = 1
# C:\Users\pablo\AppData\Local\Temp\ipykernel_10032\2281335036.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_negativo.loc[:,'target'] = 0

# %%
X_positivo.shape
# Out:
# (563, 14)

# %%
X_concat_pos = pd.concat([X_positivo, X_train[y_train == 0]])
X_concat_pos['target'] = X_concat_pos['target'].fillna(0)

# %%
X_concat_neg = pd.concat([X_negativo, X_train[y_train == 1]])
X_concat_neg['target'] = X_concat_neg['target'].fillna(1)

# %%
X_concat_pos.target.value_counts()
# Out:
# target
# 1.0    563
# 0.0    109
# Name: count, dtype: int64

# %%
X_concat_neg.target.value_counts()
# Out:
# target
# 0.0    437
# 1.0    133
# Name: count, dtype: int64

# %%
X_train[y_train == 1]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 132   42    1   1       120   295    0        1      162      0      0.0
# 75    55    0   1       135   250    0        0      161      0      1.4
# 59    57    0   0       128   303    0        0      159      0      0.0
# 93    54    0   1       132   288    1        0      159      1      0.0
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 121   59    1   0       138   271    0        0      182      0      0.0
# 20    59    1   0       135   234    0        1      161      0      0.5
# 71    51    1   2        94   227    0        1      154      1      0.0
# 106   69    1   3       160   234    1        0      131      0      0.1
# 102   63    0   1       140   195    0        1      179      0      0.0
#
#      slope  ca  thal
# 132      2   0     2
# 75       1   0     2
# 59       2   1     2
# 93       2   1     2
# 6        1   0     2
# ..     ...  ..   ...
# 121      2   0     2
# 20       1   0     3
# 71       2   1     3
# 106      1   1     2
# 102      2   2     2
#
# [133 rows x 13 columns]

# %%
from imblearn.over_sampling import SMOTE

smote_positivo = SMOTE(random_state=meuSeed)
X_resample_pos, y_resample_pos = smote_positivo.fit_resample(X_concat_pos.iloc[:,:-1], X_concat_pos.target)

smote_negativo = SMOTE(random_state=meuSeed)
X_resample_neg, y_resample_neg = smote_negativo.fit_resample(X_concat_neg.iloc[:,:-1], X_concat_neg.target)

# %%
y_resample_pos.value_counts()
# Out:
# target
# 1.0    563
# 0.0    563
# Name: count, dtype: int64

# %%
y_resample_neg.value_counts()
# Out:
# target
# 0.0    437
# 1.0    437
# Name: count, dtype: int64

# %%
X_resample_neg['target'] = y_resample_neg
X_resample_pos['target'] = y_resample_pos

df_resample = pd.concat([X_resample_neg, X_resample_pos])

X_train = df_resample.iloc[:,:-1]
y_train = df_resample.target

# %%
df_resample
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang   oldpeak  \
# 0      35    1   0       126   282    0        0      156      1  0.000000
# 1      63    1   0       130   330    1        0      132      1  1.800000
# 2      56    1   0       132   184    0        0      105      1  2.100000
# 3      63    0   0       124   197    0        1      136      1  0.000000
# 4      61    1   0       148   203    0        1      161      0  0.000000
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...       ...
# 1121   61    0   1       134   264    0        0       99      0  1.118006
# 1122   66    1   1       149   212    0        0      144      0  1.151777
# 1123   61    1   0       140   188    0        0      145      1  3.906702
# 1124   57    1   0       145   217    0        1      105      0  2.046807
# 1125   59    1   0       140   177    0        0      160      1  0.342034
#
#       slope  ca  thal  target
# 0         2   0     3     0.0
# 1         2   3     3     0.0
# 2         1   1     1     0.0
# 3         1   0     2     0.0
# 4         2   1     3     0.0
# ...     ...  ..   ...     ...
# 1121      1   0     3     0.0
# 1122      1   0     2     0.0
# 1123      1   1     3     0.0
# 1124      0   0     3     0.0
# 1125      2   1     3     0.0
#
# [2000 rows x 14 columns]

# %%
# Instanciar o modelo com 3 vizinhos
modeloKNN = KNeighborsClassifier(n_neighbors=3)
# Ajustar o modelo aos dados de treino (treinar)
modeloKNN.fit(X_train, y_train)

print('Acurácia do modelo KNN: {:.2f}%'.format(
    modeloKNN.score(X_test, y_test)*100
    ))

print(classification_report(y_test, modeloKNN.predict(X_test)))
# Out:
# Acurácia do modelo KNN: 63.93%
#               precision    recall  f1-score   support
#
#            0       0.61      0.66      0.63        29
#            1       0.67      0.62      0.65        32
#
#     accuracy                           0.64        61
#    macro avg       0.64      0.64      0.64        61
# weighted avg       0.64      0.64      0.64        61

# %%
# Instanciar o modelo com 3 vizinhos
modeloTree = DecisionTreeClassifier(random_state=meuSeed)
# Ajustar o modelo aos dados de treino (treinar)
modeloTree.fit(X_train, y_train)

print('Acurácia do modelo DT: {:.2f}%'.format(
    modeloTree.score(X_test, y_test)*100
    ))

print(classification_report(y_test, modeloTree.predict(X_test)))
# Out:
# Acurácia do modelo DT: 81.97%
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81        29
#            1       0.84      0.81      0.83        32
#
#     accuracy                           0.82        61
#    macro avg       0.82      0.82      0.82        61
# weighted avg       0.82      0.82      0.82        61

# %%
# Instanciar o modelo SVM com um kernel (por exemplo, linear)
modeloSVM = SVC(kernel='linear', random_state=meuSeed)
# Ajustar o modelo aos dados de treino (treinar)
modeloSVM.fit(X_train, y_train)

print('Acurácia do modelo SVM: {:.2f}%'.format(
    modeloSVM.score(X_test, y_test) * 100
))

print(classification_report(y_test, modeloSVM.predict(X_test)))
# Out:
# Acurácia do modelo SVM: 85.25%
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85        29
#            1       0.87      0.84      0.86        32
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61
